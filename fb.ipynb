# %%
import requests
import pandas as pd 
from dateutil.parser import parse
import jieba
import jieba.analyse


# Get your token at https://developers.facebook.com/tools/explorer/
token = '' 

fanpage = {
    "360450250740751": "小米台灣 Mi Taiwan",
    "1403439883268756": "OPPO",
    "219449834741698": "Huawei Mobile"
}
fanpage_id = '360450250740751'

#抓取貼文時間、ID、內文、分享內容
res = requests.get('https://graph.facebook.com/v2.9/{}/posts?limit=100&access_token={}'.format(fanpage_id, token))

#建立空的list
posts = []
page = 1
while 'paging' in res.json():
    print('目前正在抓取第%d頁' % page)
    for post in res.json()['data']:
        #透過貼文ID來抓取讚數與分享數
        res2 = requests.get('https://graph.facebook.com/v2.8/{}?fields=likes.limit(0).summary(True), shares&access_token={}'.format(post['id'], token))
        
        if 'likes' in res2.json():
            likes = res2.json()['likes']['summary'].get('total_count')
        else:
            likes = 0
            
        if 'shares' in res2.json():
            shares = res2.json()['shares'].get('count')
        else:
            shares = 0
        print(parse(post['created_time']))
        posts.append([parse(post['created_time']), 
                      "fb.com/" + str(post['id']), 
                      post.get('message'), 
                      post.get('story'), 
                      likes, 
                      shares
                     ])
        
    if 'next' in res.json()['paging']:
        res = requests.get(res.json()['paging']['next'])
        page += 1
    else:
        break
        
print('抓取結束!')

#檔案輸出

df = pd.DataFrame(posts)
df.columns = ['time', 'post_id', 'content', 'post_type', 'like', 'like']
df.to_csv(fanpage[fanpage_id] + '.csv', index=False)
# 小米 - 26頁 Timeout
# OPPO - 27頁 timeout
# Out:
# 目前正在抓取第1頁
# 2018-06-11 10:00:01+00:00
# 2018-06-11 04:00:01+00:00
# 2018-06-10 04:00:01+00:00
# 2018-06-09 04:00:00+00:00
# 2018-06-08 04:01:28+00:00
# 2018-06-07 04:00:00+00:00
# 2018-06-06 04:00:01+00:00
# 2018-06-05 04:34:07+00:00
# 2018-06-04 04:11:51+00:00
# 2018-06-03 15:30:00+00:00
# 2018-06-02 04:00:01+00:00
# 2018-06-01 04:45:37+00:00
# 2018-05-31 09:04:51+00:00
# 2018-05-31 03:00:43+00:00
# 2018-05-30 04:42:39+00:00
# 2018-05-29 10:09:49+00:00
# 2018-05-29 09:46:29+00:00
# 2018-05-29 04:00:01+00:00
# 2018-05-28 04:56:44+00:00
# 2018-05-27 04:00:01+00:00
# 2018-05-26 04:00:00+00:00
# 2018-05-25 04:00:01+00:00
# 2018-05-24 03:50:00+00:00
# 2018-05-23 04:00:01+00:00
# 2018-05-22 02:00:01+00:00
# 2018-05-21 04:00:00+00:00
# 2018-05-20 04:00:01+00:00
# 2018-05-19 04:00:01+00:00
# 2018-05-18 04:00:10+00:00
# 2018-05-17 04:00:08+00:00
# 2018-05-16 10:00:09+00:00
# 2018-05-16 04:00:01+00:00
# 2018-05-15 08:11:00+00:00
# 2018-05-15 02:00:00+00:00
# 2018-05-14 10:00:00+00:00
# ...

# %%
df = pd.DataFrame(posts)
df.columns = ['time', 'post_id', 'content', 'post_type', 'like', 'like']
df.to_csv( fanpage[fanpage_id] + '.csv', index=False)

# %%
# for idx, row in df[:3].iterrows():
#     print("\n", idx, row['粉絲專頁'])
#     for x, w in jieba.analyse.extract_tags(row['發文內容'], 30, withWeight=True):
#         print('%s %s' % (x, round(w,3)),end="  /")

# %%
df[df.content.str.contains("抽")]
# Out:
#                         time                                  post_id  \
# 6  2018-06-06 04:00:01+00:00  fb.com/360450250740751_1664894746962955
# 53 2018-05-06 12:00:01+00:00  fb.com/360450250740751_1634774613308302
# 59 2018-05-01 13:00:02+00:00  fb.com/360450250740751_1629724060480024
# 61 2018-04-30 13:00:01+00:00  fb.com/360450250740751_1629723190480111
# 63 2018-04-28 04:00:00+00:00  fb.com/360450250740751_1626746797444417
#
#                                               content post_type  like  like
# 6   前幾天，有一位米粉成功地用一首藏頭詩換走了一張F碼👏\n那位米粉說，米粉裡面有超多隱藏版高手...      None   441    23
# 53  【 5/8 春季新品發佈會好康放送！】\n\n截圖留言正確功能 小米新機送給你！\n\n小米...      None  1724   570
# 59  【來幫米姊取名字，帶走神祕小禮物！】\n\n跟米姊一樣效率超群、IQ 破表的米粉們，快來幫米...      None   410    17
# 61  【來幫米妹取名字，帶走神祕小禮物！】\n\n跟米妹一樣活力充沛、創意無限的米粉們，快來幫米妹...      None   297    18
# 63  #小米眾籌 第二波已經達標啦！！！\n#ZMI智慧雙模可充式鋰行動電源 你買了沒？😎\n這次...      None   548    12
